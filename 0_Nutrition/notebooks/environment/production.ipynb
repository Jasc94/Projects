# %%
import numpy as np
import pandas as pd

import sys, os

# Helpers
abspath = os.path.abspath
dirname = os.path.dirname
sep = os.sep

# Update sys.path for in-house libraries
folder_ = dirname(abspath(os.getcwd()))
for i in range(1): folder_ = dirname(folder_)
sys.path.append(folder_)

# In-house libraries
import src.utils.mining_data_tb as md
import src.utils.folder_tb as fo

# %%
# Path to data
production_data_path = fo.path_to_folder(2, "data" + sep + "environment")
# Load data
production_df = pd.read_csv(production_data_path + "food_production.csv")
production_df.head(2)
# Out:
#           Food product  Land use change  Animal Feed  Farm  Processing  \
# 0  Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# 1         Maize (Meal)              0.3          0.0   0.5         0.1
#
#    Transport  Packging  Retail  Total_emissions  \
# 0        0.1       0.1     0.1              1.4
# 1        0.1       0.1     0.0              1.1
#
#    Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)  ...  \
# 0                                                NaN         ...
# 1                                                NaN         ...
#
#    Freshwater withdrawals per 100g protein (liters per 100g protein)  \
# 0                                                NaN
# 1                                                NaN
#
#    Freshwater withdrawals per kilogram (liters per kilogram)  \
# 0                                                NaN
# 1                                                NaN
#
#    Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)  \
# 0                                                NaN
# 1                                                NaN
#
#    Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)  \
# 0                                                NaN
# 1                                                NaN
#
#    Land use per 1000kcal (m² per 1000kcal)  \
# 0                                      NaN
# 1                                      NaN
#
#    Land use per kilogram (m² per kilogram)  \
# 0                                      NaN
# 1                                      NaN
#
#    Land use per 100g protein (m² per 100g protein)  \
# 0                                              NaN
# 1                                              NaN
#
#    Scarcity-weighted water use per kilogram (liters per kilogram)  \
# 0                                                NaN
# 1                                                NaN
#
#    Scarcity-weighted water use per 100g protein (liters per 100g protein)  \
# 0                                                NaN
# 1                                                NaN
#
#    Scarcity-weighted water use per 1000kcal (liters per 1000 kilocalories)
# 0                                                NaN
# 1                                                NaN
#
# [2 rows x 23 columns]

# %%
production_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 23 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Food product                                                             43 non-null     object
#  1   Land use change                                                          43 non-null     float64
#  2   Animal Feed                                                              43 non-null     float64
#  3   Farm                                                                     43 non-null     float64
#  4   Processing                                                               43 non-null     float64
#  5   Transport                                                                43 non-null     float64
#  6   Packging                                                                 43 non-null     float64
#  7   Retail                                                                   43 non-null     float64
#  8   Total_emissions                                                          43 non-null     float64
#  9   Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)                 33 non-null     float64
#  10  Eutrophying emissions per kilogram (gPO₄eq per kilogram)                 38 non-null     float64
#  11  Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)    27 non-null     float64
#  12  Freshwater withdrawals per 1000kcal (liters per 1000kcal)                30 non-null     float64
#  13  Freshwater withdrawals per 100g protein (liters per 100g protein)        26 non-null     float64
#  14  Freshwater withdrawals per kilogram (liters per kilogram)                38 non-null     float64
#  15  Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)             33 non-null     float64
#  16  Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)     27 non-null     float64
#  17  Land use per 1000kcal (m² per 1000kcal)                                  33 non-null     float64
#  18  Land use per kilogram (m² per kilogram)                                  38 non-null     float64
#  19  Land use per 100g protein (m² per 100g protein)                          27 non-null     float64
#  20  Scarcity-weighted water use per kilogram (liters per kilogram)           38 non-null     float64
#  21  Scarcity-weighted water use per 100g protein (liters per 100g protein)   26 non-null     float64
#  22  Scarcity-weighted water use per 1000kcal (liters per 1000 kilocalories)  30 non-null     float64
# dtypes: float64(22), object(1)
# memory usage: 7.9+ KB

# %%
# As we have some missing values in the data, we will try to get this information from other files

# %%
# The units are liters (l): https://ourworldindata.org/environmental-impacts-of-food?country=#water-use
resources_data_path = production_data_path + "resources_use" + sep

# Load data and drop the unnecessary columns
land_use_kcal = pd.read_csv(resources_data_path + "land-use-kcal-poore.csv").drop(["Code", "Year"], axis = 1)
land_use_kg = pd.read_csv(resources_data_path + "land-use-per-kg-poore.csv").drop(["Code", "Year"], axis = 1)
land_use_protein = pd.read_csv(resources_data_path + "land-use-protein-poore.csv").drop(["Code", "Year"], axis = 1)

# Merge all the data in one dataframe
land_use = pd.merge(land_use_kcal, land_use_kg, how = "outer", on = "Entity")
land_use = pd.merge(land_use, land_use_protein, how = "outer", on = "Entity")
land_use.columns = ["Entity", "Land use per 1000kcal", "Land use per kg", "Land use per 100g protein"]
land_use.head()
# Out:
#               Entity  Land use per 1000kcal  Land use per kg  \
# 0             Apples               1.312500             0.63
# 1            Bananas               3.216667             1.93
# 2             Barley               0.222000             1.11
# 3   Beef (beef herd)             119.490842           326.21
# 4  Beef (dairy herd)              15.838828            43.24
#
#    Land use per 100g protein
# 0                  21.000000
# 1                  21.444444
# 2                        NaN
# 3                 163.595787
# 4                  21.904762

# %%
# The units are squared meters (m2): https://ourworldindata.org/environmental-impacts-of-food?country=#water-use

# Load data and drop the unnecessary columns
# We use the same path as before
water_use_kcal = pd.read_csv(resources_data_path + "freshwater-withdrawals-per-kcal.csv").drop(["Code", "Year"], axis = 1)
water_use_kg = pd.read_csv(resources_data_path + "freshwater-withdrawals-per-kg.csv").drop(["Code", "Year"], axis = 1)
water_use_protein = pd.read_csv(resources_data_path + "freshwater-withdrawals-per-protein.csv").drop(["Code", "Year"], axis = 1)

# Merge all the data in one dataframe
water_use = pd.merge(water_use_kcal, water_use_kg, how = "outer", on = "Entity")
water_use = pd.merge(water_use, water_use_protein, how = "outer", on = "Entity")
water_use.columns = ["Entity", "Freswater withdrawls per 1000kcal", "Freswater withdrawls per kg", "Freswater withdrawls per 100g protein"]
water_use.head()
# Out:
#               Entity  Freswater withdrawls per 1000kcal  \
# 0             Apples                         375.208333
# 1            Bananas                         190.833333
# 2             Barley                           3.420000
# 3   Beef (beef herd)                         531.575092
# 4  Beef (dairy herd)                         994.249084
#
#    Freswater withdrawls per kg  Freswater withdrawls per 100g protein
# 0                        180.1                            6003.333333
# 1                        114.5                            1272.222222
# 2                         17.1                                    NaN
# 3                       1451.2                             727.783350
# 4                       2714.3                            1375.025329

# %%
# We clean up a little bit the main df before merging
production_df = production_df.rename({"Food product" : "Entity", "Total_emissions" : "Total emissions"}, axis = 1)

# Now we merge everything together
resources = pd.merge(production_df, land_use, how = "outer", on = "Entity")
resources = pd.merge(resources, water_use, how = "outer", on = "Entity")

# Some cleaning and transformation
resources = resources.rename({"Entity" : "Food"}, axis = 1)
resources = resources.set_index("Food")
resources = resources.loc[:, ["Total emissions", 'Land use per 1000kcal', 'Land use per kg', 'Land use per 100g protein', 'Freswater withdrawls per 1000kcal', 'Freswater withdrawls per kg', 'Freswater withdrawls per 100g protein']]

resources.head()
# Out:
#                      Total emissions  Land use per 1000kcal  Land use per kg  \
# Food
# Wheat & Rye (Bread)              1.4                    NaN              NaN
# Maize (Meal)                     1.1                    NaN              NaN
# Barley (Beer)                    1.1                    NaN              NaN
# Oatmeal                          1.6               2.897446              7.6
# Rice                             4.0               0.759631              2.8
#
#                      Land use per 100g protein  \
# Food
# Wheat & Rye (Bread)                        NaN
# Maize (Meal)                               NaN
# Barley (Beer)                              NaN
# Oatmeal                               5.846154
# Rice                                  3.943662
#
#                      Freswater withdrawls per 1000kcal  \
# Food
# Wheat & Rye (Bread)                                NaN
# Maize (Meal)                                       NaN
# Barley (Beer)                                      NaN
# Oatmeal                                     183.911552
# Rice                                        609.983722
#
#                      Freswater withdrawls per kg  \
# Food
# Wheat & Rye (Bread)                          NaN
# Maize (Meal)                                 NaN
# Barley (Beer)                                NaN
# Oatmeal                                    482.4
# Rice                                      2248.4
#
#                      Freswater withdrawls per 100g protein
# Food
# Wheat & Rye (Bread)                                    NaN
# Maize (Meal)                                           NaN
# Barley (Beer)                                          NaN
# Oatmeal                                         371.076923
# Rice                                           3166.760563

# %%
def combine_data(column1, column2, df):
    '''
    This function combines two foods' values in the resources data. For instancem "Tofu" and "Tofu (soybeans)", as they are the same food, and one has the missing values of the other.

    args :
    column1 -> Should be the name of the food1 in the dataframe
    column2 -> Should be the name of the food2 in the dataframe
    df -> dataframe we pull the data from according to the given names
    '''
    # To store the new values of combining both columns
    new_values = []

    # Iterate through the length of the column1 (both columns should have the same length)
    for i in range(len(df.loc[column1])):
        # If column1 is nan, return the value of the other column
        if np.isnan(df.loc[column1][i]):
            new_values.append(df.loc[column2][i])
        # else, keep the one from column 1
        else:
            new_values.append(df.loc[column1][i])

    # Join the values together with an index (should be the same for both columns)
    # and transpose it
    df = pd.DataFrame(new_values, index = df.loc[column1].index, columns = [column1 + "_"])
    return df.T

# %%
tofu = combine_data("Tofu", "Tofu (soybeans)", resources)
wheat = combine_data("Wheat & Rye", "Wheat & Rye (Bread)", resources)
maize = combine_data("Maize", "Maize (Meal)", resources)
barley = combine_data("Barley", "Barley (Beer)", resources)

resources = resources.append([tofu, wheat, maize, barley])
resources = resources.drop(["Tofu", "Tofu (soybeans)",
            "Wheat & Rye", "Wheat & Rye (Bread)",
            "Maize", "Maize (Meal)",
            "Barley", "Barley (Beer)",])

resources = resources.rename({'Tofu_': "Tofu", 'Wheat & Rye_': "Wheat & Rye", 'Maize_': "Maize",
       'Barley_': "Barley"})
resources.index
# Out:
# Index(['Oatmeal', 'Rice', 'Potatoes', 'Cassava', 'Cane Sugar', 'Beet Sugar',
#        'Other Pulses', 'Peas', 'Nuts', 'Groundnuts', 'Soymilk', 'Soybean Oil',
#        'Palm Oil', 'Sunflower Oil', 'Rapeseed Oil', 'Olive Oil', 'Tomatoes',
#        'Onions & Leeks', 'Root Vegetables', 'Brassicas', 'Other Vegetables',
#        'Citrus Fruit', 'Bananas', 'Apples', 'Berries & Grapes', 'Wine',
#        'Other Fruit', 'Coffee', 'Dark Chocolate', 'Beef (beef herd)',
#        'Beef (dairy herd)', 'Lamb & Mutton', 'Pig Meat', 'Poultry Meat',
#        'Milk', 'Cheese', 'Eggs', 'Fish (farmed)', 'Shrimps (farmed)',
#        'Prawns (farmed)', 'Grains', 'Tofu', 'Wheat & Rye', 'Maize', 'Barley'],
#       dtype='object')

# %%
# Separate food products into two categories: plant-based and animal-based
plant_based = ['Oatmeal', 'Rice', 'Potatoes', 'Cassava', 'Cane Sugar', 'Beet Sugar',
       'Other Pulses', 'Peas', 'Nuts', 'Groundnuts', 'Soymilk', 'Soybean Oil',
       'Palm Oil', 'Sunflower Oil', 'Rapeseed Oil', 'Olive Oil', 'Tomatoes',
       'Onions & Leeks', 'Root Vegetables', 'Brassicas', 'Other Vegetables',
       'Citrus Fruit', 'Bananas', 'Apples', 'Berries & Grapes', 'Wine',
       'Other Fruit', 'Coffee', 'Dark Chocolate', 'Tofu', 'Wheat & Rye', 'Maize', 'Barley']

animal_based = ['Beef (beef herd)', 'Beef (dairy herd)', 'Lamb & Mutton', 'Pig Meat',
       'Poultry Meat', 'Milk', 'Cheese', 'Eggs', 'Fish (farmed)',
       'Shrimps (farmed)']

# Create a new column: origin
resources["Origin"] = None

# Replace the Nones in the new "Origin" column for the corresponding values, depending on the procedence
resources.loc[plant_based, "Origin"] = "Plant-based"
resources.loc[animal_based, "Origin"] = "Animal-based"

# %%
resources
# Out:
#                    Total emissions  Land use per 1000kcal  Land use per kg  \
# Oatmeal                        1.6               2.897446             7.60
# Rice                           4.0               0.759631             2.80
# Potatoes                       0.3               1.202186             0.88
# Cassava                        0.9               1.858316             1.81
# Cane Sugar                     2.6               0.581197             2.04
# Beet Sugar                     1.4               0.521368             1.83
# Other Pulses                   1.6               4.565982            15.57
# Peas                           0.8               2.156069             7.46
# Nuts                           0.2               2.107317            12.96
# Groundnuts                     2.4               1.570690             9.11
# Soymilk                        1.0                    NaN             0.66
# Soybean Oil                    6.0                    NaN            10.52
# Palm Oil                       7.6               0.273756             2.42
# Sunflower Oil                  3.5               1.997738            17.66
# Rapeseed Oil                   3.7               1.202489            10.63
# Olive Oil                      6.0               2.976244            26.31
# Tomatoes                       1.4               4.210526             0.80
# Onions & Leeks                 0.3               1.054054             0.39
# Root Vegetables                0.3               0.891892             0.33
# Brassicas                      0.4               3.235294             0.55
# Other Vegetables               0.5                    NaN             0.38
# Citrus Fruit                   0.3               2.687500             0.86
# Bananas                        0.8               3.216667             1.93
# Apples                         0.3               1.312500             0.63
# Berries & Grapes               1.1               4.228070             2.41
# Wine                           1.4                    NaN             1.78
# Other Fruit                    0.7                    NaN             0.89
# Coffee                        16.5              38.607143            21.62
# Dark Chocolate                18.7              13.338491            68.96
# Beef (beef herd)              59.6             119.490842           326.21
# Beef (dairy herd)             21.1              15.838828            43.24
# Lamb & Mutton                 24.5             116.659306           369.81
# Pig Meat                       7.2               7.263598            17.36
# Poultry Meat                   6.1               6.605405            12.22
# Milk                           2.8              14.916667             8.95
# Cheese                        21.2              22.684755            87.79
# Eggs                           4.5               4.354167             6.27
# Fish (farmed)                  5.1               4.698324             8.41
# Shrimps (farmed)              11.8                    NaN              NaN
# Prawns (farmed)                NaN               2.883495             2.97
# Grains                         NaN                    NaN              NaN
# Tofu                           3.0               1.298893             3.52
# Wheat & Rye                    1.4               1.439075             3.85
# Maize                          1.1               0.650083             2.94
# Barley                         1.1               0.222000             1.11
#
#                    Land use per 100g protein  \
# Oatmeal                             5.846154
# Rice                                3.943662
# Potatoes                            5.176471
# Cassava                            20.111111
# Cane Sugar                               NaN
# Beet Sugar                               NaN
# Other Pulses                        7.272303
# Peas                                3.357336
# Nuts                                7.936314
# Groundnuts                          3.479756
# Soymilk                                  NaN
# Soybean Oil                              NaN
# Palm Oil                                 NaN
# Sunflower Oil                            NaN
# Rapeseed Oil                             NaN
# Olive Oil                                NaN
# Tomatoes                            7.272727
# Onions & Leeks                      3.000000
# Root Vegetables                     3.300000
# Brassicas                           5.000000
# Other Vegetables                         NaN
# Citrus Fruit                       14.333333
# Bananas                            21.444444
# Apples                             21.000000
# Berries & Grapes                   24.100000
# Wine                                     NaN
# Other Fruit                              NaN
# Coffee                             27.025000
# Dark Chocolate                    137.920000
# Beef (beef herd)                  163.595787
# Beef (dairy herd)                  21.904762
# Lamb & Mutton                     184.812594
# Pig Meat                           10.729295
# Poultry Meat                        7.055427
# Milk                               27.121212
# Cheese                             39.759964
# Eggs                                5.650685
# Fish (farmed)                       3.687788
# Shrimps (farmed)                         NaN
# Prawns (farmed)                     2.010833
# Grains                              4.600000
# Tofu                                2.200000
# Wheat & Rye                         3.155738
# Maize                               3.094737
# Barley                                   NaN
#
#                    Freswater withdrawls per 1000kcal  \
# Oatmeal                                   183.911552
# Rice                                      609.983722
# Potatoes                                   80.737705
# Cassava                                          NaN
# Cane Sugar                                176.666667
# Beet Sugar                                 62.022792
# Other Pulses                                     NaN
# Peas                                             NaN
# Nuts                                      672.162602
# Groundnuts                                319.362069
# Soymilk                                          NaN
# Soybean Oil                                      NaN
# Palm Oil                                    0.723982
# Sunflower Oil                             114.015837
# Rapeseed Oil                               26.889140
# Olive Oil                                 242.285068
# Tomatoes                                 1946.315789
# Onions & Leeks                             38.648649
# Root Vegetables                            76.756757
# Brassicas                                 702.352941
# Other Vegetables                                 NaN
# Citrus Fruit                              258.437500
# Bananas                                   190.833333
# Apples                                    375.208333
# Berries & Grapes                          736.140351
# Wine                                             NaN
# Other Fruit                                      NaN
# Coffee                                     46.250000
# Dark Chocolate                            104.564797
# Beef (beef herd)                          531.575092
# Beef (dairy herd)                         994.249084
# Lamb & Mutton                             568.706625
# Pig Meat                                  751.380753
# Poultry Meat                              356.756757
# Milk                                     1047.000000
# Cheese                                   1448.372093
# Eggs                                      401.180556
# Fish (farmed)                            2062.178771
# Shrimps (farmed)                                 NaN
# Prawns (farmed)                          3413.009709
# Grains                                           NaN
# Tofu                                       54.833948
# Wheat & Rye                               242.026217
# Maize                                      47.694859
# Barley                                      3.420000
#
#                    Freswater withdrawls per kg  \
# Oatmeal                                  482.4
# Rice                                    2248.4
# Potatoes                                  59.1
# Cassava                                    0.0
# Cane Sugar                               620.1
# Beet Sugar                               217.7
# Other Pulses                             435.7
# Peas                                     396.6
# Nuts                                    4133.8
# Groundnuts                              1852.3
# Soymilk                                   27.8
# Soybean Oil                              414.6
# Palm Oil                                   6.4
# Sunflower Oil                           1007.9
# Rapeseed Oil                             237.7
# Olive Oil                               2141.8
# Tomatoes                                 369.8
# Onions & Leeks                            14.3
# Root Vegetables                           28.4
# Brassicas                                119.4
# Other Vegetables                         102.5
# Citrus Fruit                              82.7
# Bananas                                  114.5
# Apples                                   180.1
# Berries & Grapes                         419.6
# Wine                                      78.9
# Other Fruit                              153.5
# Coffee                                    25.9
# Dark Chocolate                           540.6
# Beef (beef herd)                        1451.2
# Beef (dairy herd)                       2714.3
# Lamb & Mutton                           1802.8
# Pig Meat                                1795.8
# Poultry Meat                             660.0
# Milk                                     628.2
# Cheese                                  5605.2
# Eggs                                     577.7
# Fish (farmed)                           3691.3
# Shrimps (farmed)                           NaN
# Prawns (farmed)                         3515.4
# Grains                                     NaN
# Tofu                                     148.6
# Wheat & Rye                              647.5
# Maize                                    215.7
# Barley                                    17.1
#
#                    Freswater withdrawls per 100g protein        Origin
# Oatmeal                                       371.076923   Plant-based
# Rice                                         3166.760563   Plant-based
# Potatoes                                      347.647059   Plant-based
# Cassava                                              NaN   Plant-based
# Cane Sugar                                           NaN   Plant-based
# Beet Sugar                                           NaN   Plant-based
# Other Pulses                                  203.503036   Plant-based
# Peas                                          178.487849   Plant-based
# Nuts                                         2531.414574   Plant-based
# Groundnuts                                    707.524828   Plant-based
# Soymilk                                              NaN   Plant-based
# Soybean Oil                                          NaN   Plant-based
# Palm Oil                                             NaN   Plant-based
# Sunflower Oil                                        NaN   Plant-based
# Rapeseed Oil                                         NaN   Plant-based
# Olive Oil                                            NaN   Plant-based
# Tomatoes                                     3361.818182   Plant-based
# Onions & Leeks                                110.000000   Plant-based
# Root Vegetables                               284.000000   Plant-based
# Brassicas                                    1085.454545   Plant-based
# Other Vegetables                                     NaN   Plant-based
# Citrus Fruit                                 1378.333333   Plant-based
# Bananas                                      1272.222222   Plant-based
# Apples                                       6003.333333   Plant-based
# Berries & Grapes                             4196.000000   Plant-based
# Wine                                                 NaN   Plant-based
# Other Fruit                                          NaN   Plant-based
# Coffee                                         32.375000   Plant-based
# Dark Chocolate                               1081.200000   Plant-based
# Beef (beef herd)                              727.783350  Animal-based
# Beef (dairy herd)                            1375.025329  Animal-based
# Lamb & Mutton                                 900.949525  Animal-based
# Pig Meat                                     1109.888752  Animal-based
# Poultry Meat                                  381.062356  Animal-based
# Milk                                         1903.636364  Animal-based
# Cheese                                       2538.586957  Animal-based
# Eggs                                          520.638068  Animal-based
# Fish (farmed)                                1618.636264  Animal-based
# Shrimps (farmed)                                     NaN  Animal-based
# Prawns (farmed)                              2380.094787          None
# Grains                                               NaN          None
# Tofu                                           92.875000   Plant-based
# Wheat & Rye                                   530.737705   Plant-based
# Maize                                         227.052632   Plant-based
# Barley                                               NaN   Plant-based

# %%
# Let's save the cleaned dataframe
#resources.to_csv(production_data_path + "resources.csv")

# %%
def color_mapper(df):
    color_map = {}

    for ind, row in df.iterrows():
        if row["Origin"] == "Plant-based":
            color_map[ind] = "blue"
        else:
            color_map[ind] = "red"

    return color_map

# %%
color_mapper(resources)
# Out:
# {'Oatmeal': 'blue',
#  'Rice': 'blue',
#  'Potatoes': 'blue',
#  'Cassava': 'blue',
#  'Cane Sugar': 'blue',
#  'Beet Sugar': 'blue',
#  'Other Pulses': 'blue',
#  'Peas': 'blue',
#  'Nuts': 'blue',
#  'Groundnuts': 'blue',
#  'Soymilk': 'blue',
#  'Soybean Oil': 'blue',
#  'Palm Oil': 'blue',
#  'Sunflower Oil': 'blue',
#  'Rapeseed Oil': 'blue',
#  'Olive Oil': 'blue',
#  'Tomatoes': 'blue',
#  'Onions & Leeks': 'blue',
#  'Root Vegetables': 'blue',
#  'Brassicas': 'blue',
#  'Other Vegetables': 'blue',
#  'Citrus Fruit': 'blue',
#  'Bananas': 'blue',
#  'Apples': 'blue',
#  'Berries & Grapes': 'blue',
#  'Wine': 'blue',
#  'Other Fruit': 'blue',
#  'Coffee': 'blue',
#  'Dark Chocolate': 'blue',
#  'Beef (beef herd)': 'red',
#  'Beef (dairy herd)': 'red',
#  'Lamb & Mutton': 'red',
#  'Pig Meat': 'red',
#  'Poultry Meat': 'red',
#  'Milk': 'red',
#  'Cheese': 'red',
#  'Eggs': 'red',
#  'Fish (farmed)': 'red',
#  'Shrimps (farmed)': 'red',
#  'Prawns (farmed)': 'red',
#  'Grains': 'red',
#  'Tofu': 'blue',
#  'Wheat & Rye': 'blue',
#  'Maize': 'blue',
#  'Barley': 'blue'}
